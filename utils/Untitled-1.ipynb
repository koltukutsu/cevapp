# %%
import json

# %%
with open("assets/data/questions_second.json", "r") as json_file:
    questions = json.load(json_file)

# %%
questions
# Out:
# {'untouched': [{'id': '13050ea6-4568-11ed-8f5a-bc17b8019234',
#    'question': 'Do you have a favourite book or author?\n',
#    'category': 'Books',
#    'level': 'Advanced'},
#   {'id': '13050ea7-4568-11ed-90ee-bc17b8019234',
#    'question': 'What genre of books to you like to read?\n',
#    'category': 'Books',
#    'level': 'Advanced'},
#   {'id': '13050ea8-4568-11ed-b1a9-bc17b8019234',
#    'question': 'At what time of day do you like to read?\n',
#    'category': 'Books',
#    'level': 'Intermediate'},
#   {'id': '13050ea9-4568-11ed-81f1-bc17b8019234',
#    'question': 'How do you choose what books to read?\n',
#    'category': 'Books',
#    'level': 'Advanced'},
#   {'id': '13050eaa-4568-11ed-9d33-bc17b8019234',
#    'question': 'Do you like reading e-books? Do you think they are the future?\n',
#    'category': 'Books',
#    'level': 'Beginner'},
#   {'id': '13050eab-4568-11ed-8626-bc17b8019234',
# ...

# %%
df = questions["untouched"]

# %%
len(df)
# Out:
# 804

# %%
import pandas as pd

# %%
df_mine = pd.DataFrame(df)

# %%
df_mine
# Out:
#                                        id  \
# 0    13050ea6-4568-11ed-8f5a-bc17b8019234
# 1    13050ea7-4568-11ed-90ee-bc17b8019234
# 2    13050ea8-4568-11ed-b1a9-bc17b8019234
# 3    13050ea9-4568-11ed-81f1-bc17b8019234
# 4    13050eaa-4568-11ed-9d33-bc17b8019234
# ..                                    ...
# 799  1305d26e-4568-11ed-ada7-bc17b8019234
# 800  1305d26f-4568-11ed-918d-bc17b8019234
# 801  1305d270-4568-11ed-9f49-bc17b8019234
# 802  1305d271-4568-11ed-a01a-bc17b8019234
# 803  1305d272-4568-11ed-86f4-bc17b8019234
#
#                                               question    category  \
# 0            Do you have a favourite book or author?\n       Books
# 1           What genre of books to you like to read?\n       Books
# 2           At what time of day do you like to read?\n       Books
# 3              How do you choose what books to read?\n       Books
# 4    Do you like reading e-books? Do you think they...       Books
# ...

# %%
df_mine.category.value_counts()
# Out:
# Philosophy    306
# Life          174
# Books         158
# Technology     77
# Health         26
# History        21
# Science        21
# Musics         21
# Name: category, dtype: int64

# %%
df_mine.level.value_counts()
# Out:
# Advanced        221
# Intermediate    208
# Beginner        195
# Native-Like     180
# Name: level, dtype: int64
